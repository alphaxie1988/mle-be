# %%
import sqlalchemy
import pandas as pd

def init_db_connection():
    db_config = {
        'pool_size': 5,
        'max_overflow': 2,
        'pool_timeout': 30,
        'pool_recycle': 1800,
    }
    return init_unix_connection_engine(db_config)


def init_unix_connection_engine(db_config):
    # Dev
    pool = sqlalchemy.create_engine(
        sqlalchemy.engine.url.URL(
            host="127.0.0.1",
            port="5432",
            drivername="postgres+pg8000",
            username="postgres",
            password="Password123ajjw",
            database="mycareersfuture",
        ),
        **db_config
    )

    pool.dialect.description_encoding = None
    return pool


db = init_db_connection()
with db.connect() as conn:
    df_raw = pd.read_sql("select * from careers", conn)
df_raw
# Out:
#                                     uuid  \
# 0       7dcca2c3a2728db9289cb6c1dc028a07
# 1       149fec9a65126ea3f99177d5b1a8e726
# 2       7ff1b6629ae11b6efc4c634187efff67
# 3       8fbdde8a4673a9dc8f9b7920d99cd314
# 4       3320d5c808cab29497cfe6b9b1e1744c
# ...                                  ...
# 102276  ee62c9eb960e138205c324915a4405e4
# 102277  c6744398f40719db83177bff8e1e3322
# 102278  b1db2ee11239e8f210be1cc0a0ed127f
# 102279  f26bff21ee09d58f04ec50434a41b88c
# 102280  2ff1cf735622e4084ee7958b4a663313
#
#                                                     title  \
# 0                                 Frontend Developer (SF)
# 1        APJ Cyber Resiliency Business Development Exe...
# 2       Health Informatics Specialist - Business Devel...
# 3                                      Investment Manager
# 4                                         PART TIMER CREW
# ...                                                   ...
# 102276                     Project Manager (Scrum Master)
# 102277                                       WSHE Officer
# 102278                        Executive - Human Resources
# 102279  Associate - Litigation, Insolvency & Restructu...
# 102280                                   Account manager
#
#                                               description  \
# 0       Job Description This is a remote position. Des...
# 1       At Dell Technologies, we’re proud to be known ...
# 2       Job Description  Do you have a passion for Hea...
# 3       Auric Pacific Group Auric is a Singapore-based...
# 4       Email: recruit@qqrice.sg Hotline | WhatApps: 8...
# ...                                                   ...
# 102276  Description:  Facilitate team for better creat...
# 102277  Responsibilities: • Responsible for the implem...
# 102278  Responsibilities:  Talent Acquisition  Respons...
# 102279  Why Harneys?  Harneys is a global offshore law...
# 102280  Account manager – Singapore AMICULUM is lookin...
#
#         minimumyearsexperience  \
# 0                            1
# 1                           15
# 2                           10
# 3                            3
# 4                            1
# ...                        ...
# 102276                       2
# 102277                       5
# 102278                       3
# 102279                       2
# 102280                       2
#
#                                                    skills  numberofvacancies  \
# 0       Git|CSS3|CSS|HTML|Fundraising|Financials|JavaS...                  1
# 1       Outsourcing|Interpersonal Skills|Channel|Selli...                  1
# 2       Clinical|clinical imaging|Emerging Technology|...                  1
# 3       Negotiation|Leadership|Growth Strategies|Due D...                  1
# 4       Microsoft PowerPoint|Ingredients|Written Engli...                  2
# ...                                                   ...                ...
# 102276  Negotiation|Feasibility Studies|Leadership|App...                  2
# 102277  Fire Safety|Microsoft Office|Construction|Work...                  1
# 102278  Analytical Skills|Administration|Payroll|Emplo...                  2
# 102279  Commercial Litigation|Strong Attention To Deta...                  1
# 102280  Pharmaceutical Industry|Healthcare Communicati...                  1
#
#                          categories      employmenttypes    positionlevels  \
# 0            Information Technology  Permanent|Full Time         Executive
# 1            Information Technology            Full Time      Professional
# 2                    Sales / Retail            Full Time  Senior Executive
# 3                            Others  Permanent|Full Time           Manager
# 4                               F&B            Part Time     Non-executive
# ...                             ...                  ...               ...
# 102276       Information Technology            Full Time           Manager
# 102277    Building and Construction            Full Time         Executive
# 102278    Engineering|Manufacturing  Permanent|Full Time         Executive
# 102279                        Legal            Permanent      Professional
# 102280  Healthcare / Pharmaceutical            Permanent      Professional
#
#         totalnumberofview  ...  originalpostingdate  expirydate  \
# 0                      96  ...           2022-05-25  2022-06-24
# 1                      52  ...           2022-05-12  2022-06-11
# 2                      73  ...           2022-05-25  2022-06-24
# 3                     183  ...           2022-05-06  2022-07-06
# 4                      56  ...           2022-05-06  2022-07-06
# ...                   ...  ...                  ...         ...
# 102276                100  ...           2022-04-26  2022-07-07
# 102277                339  ...           2022-04-26  2022-07-07
# 102278                134  ...           2022-04-23  2022-07-07
# 102279                183  ...           2022-04-23  2022-07-07
# 102280                 36  ...           2022-05-30  2022-06-29
#
#                                                     links  \
# 0       https://api.mycareersfuture.gov.sg/v2/jobs/7dc...
# 1       https://api.mycareersfuture.gov.sg/v2/jobs/149...
# 2       https://api.mycareersfuture.gov.sg/v2/jobs/7ff...
# 3       https://api.mycareersfuture.gov.sg/v2/jobs/8fb...
# 4       https://api.mycareersfuture.gov.sg/v2/jobs/332...
# ...                                                   ...
# 102276  https://api.mycareersfuture.gov.sg/v2/jobs/ee6...
# 102277  https://api.mycareersfuture.gov.sg/v2/jobs/c67...
# 102278  https://api.mycareersfuture.gov.sg/v2/jobs/b1d...
# 102279  https://api.mycareersfuture.gov.sg/v2/jobs/f26...
# 102280  https://api.mycareersfuture.gov.sg/v2/jobs/2ff...
#
#                                          postedcompany minsalary  maxsalary  \
# 0                           GLINTS SINGAPORE PTE. LTD.     11400      34000
# 1                  DELL GLOBAL B.V. (SINGAPORE BRANCH)     18000      36000
# 2        AMAZON WEB SERVICES SINGAPORE PRIVATE LIMITED     17000      34000
# 3                          AURIC PACIFIC GROUP LIMITED         1       9999
# 4                              NATURAL GRAIN PTE. LTD.         8         10
# ...                                                ...       ...        ...
# 102276                             WEBSPARKS PTE. LTD.      4500       6500
# 102277  STRAITS CONSTRUCTION SINGAPORE PRIVATE LIMITED      4200       7500
# 102278                         ASE SINGAPORE PTE. LTD.      3000       4500
# 102279         HARNEY WESTWOOD & RIEGELS SINGAPORE LLP      6000      12000
# 102280            AMICULUM (SINGAPORE) PRIVATE LIMITED      4167       5833
#
#         avgsalary                  crawldate status  \
# 0           22700 2022-06-07 09:48:02.715376      4
# 1           27000 2022-06-07 09:59:50.744071      4
# 2           25500 2022-06-07 09:47:19.825844      4
# 3            5000 2022-06-07 09:35:36.841212      4
# 4               9 2022-06-07 09:35:37.071868      4
# ...           ...                        ...    ...
# 102276       5500 2022-06-07 09:34:48.771042      2
# 102277       5850 2022-06-07 09:34:48.772793      2
# 102278       3750 2022-06-07 09:34:48.994356      2
# 102279       9000 2022-06-07 09:34:48.997428      2
# 102280       5000 2022-06-07 09:42:37.925855      2
#
#                                               remarks
# 0       Salary Range too Wide|Admin marked as not OK|
# 1       Salary Range too Wide|Admin marked as not OK|
# 2       Salary Range too Wide|Admin marked as not OK|
# 3       Min salary is too low|Admin marked as not OK|
# 4       Min salary is too low|Admin marked as not OK|
# ...                                               ...
# 102276
# 102277
# 102278
# 102279
# 102280
#
# [102281 rows x 21 columns]

# %%
df_raw['title']
# Out:
# 0                                   Frontend Developer (SF)
# 1          APJ Cyber Resiliency Business Development Exe...
# 2         Health Informatics Specialist - Business Devel...
# 3                                        Investment Manager
# 4                                           PART TIMER CREW
#                                 ...
# 102276                       Project Manager (Scrum Master)
# 102277                                         WSHE Officer
# 102278                          Executive - Human Resources
# 102279    Associate - Litigation, Insolvency & Restructu...
# 102280                                     Account manager
# Name: title, Length: 102281, dtype: object
